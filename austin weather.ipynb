# %%
import pandas as pd
df = pd.read_csv("austin_weather.csv", nrows=10)
df
# Out:
#          Date  TempHighF  TempAvgF  TempLowF  DewPointHighF  DewPointAvgF  \
# 0  21/12/2013         74        60        45             67            49
# 1  22/12/2013         56        48        39             43            36
# 2  23/12/2013         58        45        32             31            27
# 3  24/12/2013         61        46        31             36            28
# 4  25/12/2013         58        50        41             44            40
# 5  26/12/2013         57        48        39             39            36
# 6  27/12/2013         60        53        45             41            39
# 7  28/12/2013         62        51        40             43            39
# 8  29/12/2013         64        50        36             49            41
# 9  30/12/2013         44        40        35             31            26
#
#    DewPointLowF  HumidityHighPercent  HumidityAvgPercent  HumidityLowPercent  \
# ...

# %%
# %matplotlib inline
df.plot(y="TempHighF" , color="green")

# %%
df['TempLowF'].mean()
# Out:
# 35.73684210526316

# %%
df[['Date','TempHighF']]
# Out:
#             Date  TempHighF
# 0     21/12/2013       74.0
# 1     22/12/2013       56.0
# 2     23/12/2013       58.0
# 3     24/12/2013       61.0
# 4     25/12/2013       58.0
# ...          ...        ...
# 1314         NaN        NaN
# 1315  28/07/2017        NaN
# 1316  29/07/2017        NaN
# 1317  30/07/2017        NaN
# 1318  31/07/2017        NaN
#
# [1319 rows x 2 columns]

# %%
df.describe()
# Out:
#        TempHighF   TempAvgF   TempLowF  DewPointHighF  DewPointAvgF  \
# count  19.000000  19.000000  19.000000      19.000000     19.000000
# mean   57.789474  47.000000  35.736842      41.368421     32.789474
# std     8.941656   7.218803   6.631927      11.757790     11.360648
# min    36.000000  29.000000  22.000000      15.000000      8.000000
# 25%    55.000000  44.500000  32.500000      33.500000     26.500000
# 50%    58.000000  47.000000  36.000000      41.000000     36.000000
# 75%    61.500000  50.500000  40.000000      50.000000     40.500000
# max    74.000000  60.000000  45.000000      67.000000     49.000000
#
#        DewPointLowF  HumidityHighPercent  HumidityAvgPercent  \
# count     19.000000            19.000000            19.00000
# mean      25.368421            82.210526            61.00000
# std       10.919964            10.809353            10.76517
# min        2.000000            50.000000            38.00000
# ...

# %%
df[df.TempHighF>=32]
# Out:
#           Date  TempHighF  TempAvgF  TempLowF  DewPointHighF  DewPointAvgF  \
# 0   21/12/2013       74.0      60.0      45.0           67.0          49.0
# 1   22/12/2013       56.0      48.0      39.0           43.0          36.0
# 2   23/12/2013       58.0      45.0      32.0           31.0          27.0
# 3   24/12/2013       61.0      46.0      31.0           36.0          28.0
# 4   25/12/2013       58.0      50.0      41.0           44.0          40.0
# 5   26/12/2013       57.0      48.0      39.0           39.0          36.0
# 6   27/12/2013       60.0      53.0      45.0           41.0          39.0
# 7   28/12/2013       62.0      51.0      40.0           43.0          39.0
# 8   29/12/2013       64.0      50.0      36.0           49.0          41.0
# 9   30/12/2013       44.0      40.0      35.0           31.0          26.0
# 10  31/12/2013       55.0      46.0      36.0           31.0          28.0
# ...

# %%
df[df.TempHighF==df['TempHighF'].max()]
# Out:
#          Date  TempHighF  TempAvgF  TempLowF  DewPointHighF  DewPointAvgF  \
# 0  21/12/2013       74.0      60.0      45.0           67.0          49.0
#
#    DewPointLowF  HumidityHighPercent  HumidityAvgPercent  HumidityLowPercent  \
# 0          43.0                 93.0                75.0                57.0
#
#    ...  SeaLevelPressureAvgInches  SeaLevelPressureLowInches  \
# 0  ...                      29.68                      29.59
#
#    VisibilityHighMiles  VisibilityAvgMiles  VisibilityLowMiles  WindHighMPH  \
# 0                 10.0                 7.0                 2.0         20.0
#
#    WindAvgMPH  Unnamed: 18  Unnamed: 19  Events
# 0         4.0          NaN          NaN     NaN
#
# [1 rows x 21 columns]

# %%
df = pd.read_xlxs("b.csv","sheet1")
df
# Out:
# <ipython-input-23-fda0d38582de>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv("b.csv","sheet1")
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-23-fda0d38582de> in <module>
# ----> 1 df = pd.read_csv("b.csv","sheet1")
#       2 df
#
# ...
